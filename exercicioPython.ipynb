# %%
print("Ola mundo")
# Out:
# Ola mundo

# %%
print("Julio Henrique Augusto de Lima")
# Out:
# Julio Henrique Augusto de Lima

# %%
print("*\n**\n***\n****\n*****")
# Out:
# *
# **
# ***
# ****
# *****

# %%
altura = float(input("Altura: "))/100
peso = float(input("Peso: "))
IMC = peso/(altura*altura)

print("IMC: " + str(IMC))
# Out:
# Altura: 150
# Peso: 80
# IMC: 35.55555555555556

# %%
x = int(2)
y = int(3)
print("x = " + str(x))
print("O valor de x + x é " + str(x+x));
print("x = ");
print(str(x + y) + " = " + str(y + x));
# Out:
# x = 2
# O valor de x + x é 4
# x =
# 5 = 5

# %%
print("A programação é aprendida escrevendo programas - Brian Kernighan")
# Out:
# A programação é aprendida escrevendo programas - Brian Kernighan

# %%
print("O Produto dos numeros entre os numeros 25 e 27 é: " + str(25*27))
# Out:
# O Produto dos numeros entre os numeros 25 e 27 é: 675

# %%
print("A média aritmética entre os números 4, 12, 15 é: " + str((4+12+15)/3))
# Out:
# A média aritmética entre os números 4, 12, 15 é: 10.333333333333334

# %%
num = input("Digite um numero inteiro")
print("O número inteiro digitado foi " + num)
# Out:
# Digite um numero inteiro5
# O número inteiro digitado foi 5

# %%
num1 = input("Digite o primeiro numero inteiro: ")
num2 = input("Digite o segundo numero inteiro: ")
print("O primeiro numero inteiro digitado é: " + num1 + "\nO segundo numero inteiro digitado é: " + num2)
# Out:
# Digite o primeiro numero inteiro: 1
# Digite o segundo numero inteiro: 2
# O primeiro numero inteiro digitado é: 1
# O segundo numero inteiro digitado é: 2

# %%
num = int(input("Digite um numero inteiro: "))
print("O antecessor deste numero é: " + str(num - 1) + "\nO sucessor deste numero é: " + str(num+1))
# Out:
# Digite um numero inteiro: 4
# O antecessor deste numero é: 3
# O sucessor deste numero é: 5

# %%
nome = input("Digite o nome do usuário: ")
end = input("Digite o Endereço do usuário: ")
tel = input("Digite o telefone do usuário: ")
print("Nome do usuário: " + nome + "\nEndereço do usuário: " + end + "\nTelefone do usuário: " + tel)
# Out:
# Digite o nome do usuário: Julio
# Digite o Endereço do usuário: endereço qualquer
# Digite o telefone do usuário: 99999999
# Nome do usuário: Julio
# Endereço do usuário: endereço qualquer
# Telefone do usuário: 99999999

# %%
num1 = int(input("Digite um numero inteiro: "))
num2 = int(input("Digite outro numero inteiro: "))
print("Resposta da multiplicação dos dois numeros inteiros é: " + str(num1*num2))
# Out:
# Digite um numero inteiro: 2
# Digite outro numero inteiro: 2
# Resposta da multiplicação dos dois numeros inteiros é: 4

# %%
numreal = float(input("Digite um numero: "))
print("A terça parte deste numero é: " + str(numreal/3))
# Out:
# Digite um numero: 3
# A terça parte deste numero é: 1.0

# %%
dividendo = int(input("Digite um numero inteiro: "))
divisor = int(input("Digite outro numero inteiro: "))

quociente = int(dividendo / divisor)
resto = int(dividendo % divisor)
print("Dividendo: " + str(dividendo) + "\nDivisor: " + str(divisor) + "\nQuociente: " + str(quociente) + "\nResto: " + str(resto))
# Out:
# Digite um numero inteiro: 5
# Digite outro numero inteiro: 3
# Dividendo: 5
# Divisor: 3
# Quociente: 1
# Resto: 2

# %%
num1 = int(input("Digite um numero inteiro: "))
num2 = int(input("Digite outro numero inteiro: "))

print("Soma: " + str(num1+num2) + "\nSubtração: " + str(num1-num2) + "\nMultiplicação: " + str(num1*num2) + "\nDivisão: " + str(num1/num2))
# Out:
# Digite um numero inteiro: 5
# Digite outro numero inteiro: 2
# Soma: 7
# Subtração: 3
# Multiplicação: 10
# Divisão: 2.5

# %%
num1 = int(input("Digite um numero inteiro: "))
num2 = int(input("Digite outro numero inteiro: "))
num3 = int(input("Digite mais um numero inteiro: "))
num4 = int(input("Digite outro numero inteiro: "))

print("A Soma dos 4 numeros digitados é: " + str(num1+num2+num3+num4))
# Out:
# Digite um numero inteiro: 1
# Digite outro numero inteiro: 2
# Digite mais um numero inteiro: 3
# Digite outro numero inteiro: 4
# A Soma dos 4 numeros digitados é: 10

# %%
num1 = int(input("Digite a nota 1: "))
num2 = int(input("Digite a nota 2: "))
num3 = int(input("Digite a nota 3: "))

print("A media aritmetica das notas é: " + str((num1+num2+num3)/3))
# Out:
# Digite a nota 1: 3
# Digite a nota 2: 3
# Digite a nota 3: 3
# A media aritmetica das notas é: 3.0

# %%
num1 = int(input("Digite a nota 1: "))
peso1 = int(input("Digite o peso da nota 1: "))
num2 = int(input("Digite a nota 2: "))
peso2 = int(input("Digite o peso da nota 2: "))
num3 = int(input("Digite a nota 3: "))
peso3 = int(input("Digite o peso da nota 3: "))

print("A media aritmetica das notas é: " + str(((num1*peso1)+(num2*peso2)+(num3*peso3))/(peso1+peso2+peso3)))
# Out:
# Digite a nota 1: 1
# Digite o peso da nota 1: 2
# Digite a nota 2: 2
# Digite o peso da nota 2: 3
# Digite a nota 3: 4
# Digite o peso da nota 3: 5
# A media aritmetica das notas é: 2.8

# %%
salario = int(input("Digite o salario sem aumento do funcionario: "))

print("O novo salario do funcionario é: " + str(salario+(salario*0.25)))
# Out:
# Digite a nota 1: 100
# O novo salario do funcionario é: 125.0

# %%
salario = int(input("Digite o salario sem aumento do funcionario: "))
aumento = int(input("Digite o percentual de aumento do funcionario: "))

print("O valor do aumento é: " + str(salario*(aumento/100)) + "\nO valor do novo salario é: " + str(salario+(salario*(aumento/100))))
# Out:
# Digite o salario sem aumento do funcionario: 100
# Digite o percentual de aumento do funcionario: 25
# O valor do aumento é: 25.0
# O valor do novo salario é: 125.0

# %%
salario = int(input("Digite o salario base do funcionario: "))

print("O salario a receber do funcionario é: " + str((salario+(salario*0.05))-(salario*0.07)))
# Out:
# Digite o salario base do funcionario: 100
# O salario a receber do funcionario é: 98.0

# %%
salario = int(input("Digite o salario base do funcionario: "))

print("O salario a receber do funcionario é: " + str((salario+50)-(salario*0.1)))
# Out:
# Digite o salario base do funcionario: 100
# O salario a receber do funcionario é: 140.0

# %%
deposito = int(input("Digite o valor do deposito: "))
juros = int(input("Digite a taxa de Juros: "))

print("Valor do rendimento: " + str(deposito*(juros/100)) + "\nNovo valor: " + str(deposito+(deposito*(juros/100))))
# Out:
# Digite o valor do deposito: 100
# Digite a taxa de Juros: 25
# Valor do rendimento: 25.0
# Novo valor: 125.0

# %%
base = float(input("Digite o valor da base do triangulo: "))
altura = float(input("Digite o valor da altura do triangulo: "))

print("A área do triangulo é:: " + str(base*altura))
# Out:
# Digite o valor da base do triangulo: 2
# Digite o valor da altura do triangulo: 2
# A área do triangulo é:: 4.0

# %%
raio = float(input("digite o valor do raio do triangulo"))

print("Valor do diametro do circulo é: " + str(raio*2) + "\nValor da circunferencia do circulo é: " + str(2*3.14*raio) + "\nValor da area do circulo é: " + str(3.14*(raio*raio)))
# Out:
# digite o valor do raio do triangulo3
# Valor do diametro do circulo é: 6.0
# Valor da circunferencia do circulo é: 18.84
# Valor da area do circulo é: 28.26

# %%
import math
num = int(input("Digite um numero positivo: "))
if(num>0):
  print("Numero ao quadrado: " + str(num*num) + "\nNumero ao cubo: " + str(num*num*num) + "\nRaiz quadrada: " + str(math.sqrt(num)))
else:
  print("Numero digitado menor ou igual a 0")
# Out:
# Digite um numero positivo: 2
# Numero ao quadrado: 4
# Numero ao cubo: 8
# Raiz quadrada: 1.4142135623730951

# %%
num = int(input("Digite um numero positivo: "))
num2 = int(input("Digite outro numero positivo"))
if(num>0):
  print(str(num) + " elevado a " + str(num2) + " é: " + str(num**num2))
else:
  print("Numero digitado menor ou igual a 0")
# Out:
# Digite um numero positivo: 2
# Digite outro numero positivo3
# 2 elevado à 3 é: 8

# %%
pes = int(input("Digite a medida em pés: "))
polegada = 12*pes
jarda = pes/3
milha = (pes/3)/1760
print("Abaixo estão as conversões: \nPolegadas: " + str(12*pes) + "\nJardas: " + str(pes/3) + "\nMilhas: " + str((pes/3)/1760))
# Out:
# Digite a medida em pés: 3
# Abaixo estão as conversões:
# Polegadas: 36
# Jardas: 1.0
# Milhas: 0.0005681818181818182
